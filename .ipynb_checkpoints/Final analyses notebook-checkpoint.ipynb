# %% [markdown]
# ## Analyzing New York City employees' payroll database
#
# ### 🤔 Does tenure affect employees' overtime pay?
#
# ### Data Source: [NYC open data](https://data.cityofnewyork.us/City-Government/Citywide-Payroll-Data-Fiscal-Year-/k397-673e/data)
#
# #### The process ####
# We started the project with some basic exploratory analyses into overtime pay for different city agencies. We were interested in practicing my newly acquired linear regression skills to see what factors could explain variance in overtime pay. That didn't lead to anything significant, so we did some more data wrangling and found some interesting patterns in overtime pay with some really strong outliers.
#
# We then reported on the outliers and sought out experts from watchdog organizations who pointed that an employees' tenure might affect how much overtime they make. In this notebook, we'll show some of the strongest outliers in overtime earned and how much their tenure affects them.

# %% [markdown]
# #### Steps
#
# 1. Identify the agencies which we'll inspect more closely. Criteria for selecting agencies: The top three that spend the most in overtime, normalized for number of employees
#
# 2. Create a smaller dataframe with employees of just these three agencies and see what factors best explain number of overtime hours for each of these three agencies individually, and then all together.
#
# 3. Introduce tenure years to step 2 and see how much of a difference that makes.
#
# 4. Plot overtime earned against tenure.

# %% [markdown]
# #### Load the data and necessary Python package imports

# %%
import pandas as pd
from plotnine import *
import statsmodels.formula.api as smf

df = pd.read_csv('Citywide_Payroll_Data__Fiscal_Year_.csv')
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.replace("-", "_")
df.columns = df.columns.str.lower()
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df.shape
# Out:
# (2864545, 17)

# %% [markdown]
# #### Cleaning the data
#
# The database includes people whose work locations are outside of NYC. For this analyses, we're only including employees with work locations in NYC boroughs. Since Staten Island wasn't listed (unless included in the "other" location, this is filtered down to Queens, Manhattan, Bronx and Brooklyn.

# %%
boroughs = ['QUEENS', 'MANHATTAN', 'BROOKLYN', 'BRONX']

# %%
df = df[df.work_location_borough.isin(boroughs)]

# %%
df.shape
# Out:
# (2760682, 17)

# %% [markdown]
# Note: This reduces the dataset by 103,863 rows.

# %%
# Here's what the data looks like
df.head(3)
# Out:
#    fiscal_year  payroll_number                agency_name last_name  \
# 0         2017             NaN  ADMIN FOR CHILDREN'S SVCS     AARON
# 1         2017             NaN  ADMIN FOR CHILDREN'S SVCS    AARONS
# 2         2017             NaN  ADMIN FOR CHILDREN'S SVCS     ABDUL
#
#   first_name mid_init agency_start_date work_location_borough  \
# 0     TERESA      NaN        03/21/2016                 BRONX
# 1    CAMELIA        M        08/08/2016              BROOKLYN
# 2     MODUPE      NaN        02/11/2008              BROOKLYN
#
#              title_description leave_status_as_of_june_30  base_salary  \
# 0  CHILD PROTECTIVE SPECIALIST                     ACTIVE    51,315.00
# 1  CHILD PROTECTIVE SPECIALIST                     ACTIVE    51,315.00
# 2  CHILD PROTECTIVE SPECIALIST                     ACTIVE    54,720.00
#
#    pay_basis  regular_hours  regular_gross_paid  ot_hours  total_ot_paid  \
# 0  per Annum       1,825.00           51,709.59    588.00      22,374.31
# 1  per Annum       1,595.55           41,960.18    121.75       3,892.19
# 2  per Annum       1,825.00           56,298.93     54.75       2,455.88
#
#    total_other_pay
# 0           639.66
# 1           108.25
# 2         3,938.75

# %%
df.groupby(by='fiscal_year').total_ot_paid.sum().round()
# Out:
# fiscal_year
# 2017   1,866,990,981.00
# 2018   1,803,832,443.00
# 2019   1,781,905,103.00
# 2020   1,866,461,730.00
# 2021   1,695,474,497.00
# Name: total_ot_paid, dtype: float64

# %% [markdown]
# #### 📝 Adding a column to calculate tenure.

# %%
df['agency_start_date'] = pd.to_datetime(df.agency_start_date, errors='coerce')
df['today'] = pd.to_datetime('today')
df['tenure_years'] = (df.today - df.agency_start_date).astype('timedelta64[Y]')

# %%
df.head(3)
# Out:
#    fiscal_year  payroll_number                agency_name last_name  \
# 0         2017             NaN  ADMIN FOR CHILDREN'S SVCS     AARON
# 1         2017             NaN  ADMIN FOR CHILDREN'S SVCS    AARONS
# 2         2017             NaN  ADMIN FOR CHILDREN'S SVCS     ABDUL
#
#   first_name mid_init agency_start_date work_location_borough  \
# 0     TERESA      NaN        2016-03-21                 BRONX
# 1    CAMELIA        M        2016-08-08              BROOKLYN
# 2     MODUPE      NaN        2008-02-11              BROOKLYN
#
#              title_description leave_status_as_of_june_30  base_salary  \
# 0  CHILD PROTECTIVE SPECIALIST                     ACTIVE    51,315.00
# 1  CHILD PROTECTIVE SPECIALIST                     ACTIVE    51,315.00
# 2  CHILD PROTECTIVE SPECIALIST                     ACTIVE    54,720.00
#
#    pay_basis  regular_hours  regular_gross_paid  ot_hours  total_ot_paid  \
# 0  per Annum       1,825.00           51,709.59    588.00      22,374.31
# 1  per Annum       1,595.55           41,960.18    121.75       3,892.19
# 2  per Annum       1,825.00           56,298.93     54.75       2,455.88
#
#    total_other_pay                      today  tenure_years
# 0           639.66 2022-05-16 22:11:42.508700          6.00
# 1           108.25 2022-05-16 22:11:42.508700          5.00
# 2         3,938.75 2022-05-16 22:11:42.508700         14.00

# %% [markdown]
# #### 📝 Which agencies spend the most on overtime?

# %%
df.groupby(by='agency_name').total_ot_paid.sum().reset_index().sort_values(by='total_ot_paid', ascending = False).head(5)
# Out:
#                   agency_name    total_ot_paid
# 125         POLICE DEPARTMENT 3,410,660,240.39
# 88            FIRE DEPARTMENT 1,596,842,055.03
# 59   DEPARTMENT OF CORRECTION   981,672,183.09
# 65   DEPARTMENT OF SANITATION   790,873,824.62
# 114     NYC HOUSING AUTHORITY   553,297,085.88

# %%
three_agencies = ['POLICE DEPARTMENT', 'FIRE DEPARTMENT', 'DEPARTMENT OF CORRECTION']

# %%
df_agencies = df[df.agency_name.isin(three_agencies)]

# %%
df_agencies
# Out:
#          fiscal_year  payroll_number               agency_name    last_name  \
# 91106           2017             NaN  DEPARTMENT OF CORRECTION        AARON
# 91107           2017             NaN  DEPARTMENT OF CORRECTION        AAYAN
# 91108           2017             NaN  DEPARTMENT OF CORRECTION        ABASI
# 91109           2017             NaN  DEPARTMENT OF CORRECTION       ABBASI
# 91110           2017             NaN  DEPARTMENT OF CORRECTION       ABBATE
# ...              ...             ...                       ...          ...
# 2864493         2021           72.00  DEPARTMENT OF CORRECTION       HARRIS
# 2864507         2021           72.00  DEPARTMENT OF CORRECTION      ACEVEDO
# 2864512         2021           56.00         POLICE DEPARTMENT          NaN
# 2864517         2021           57.00           FIRE DEPARTMENT  KALTENMEIER
# 2864520         2021           56.00         POLICE DEPARTMENT          NaN
#
#         first_name mid_init agency_start_date work_location_borough  \
# 91106      SHELLON      NaN        2010-12-16                QUEENS
# 91107      IBRAHIM      NaN        2016-06-27                QUEENS
# 91108       JUSTIN      NaN        2017-06-19                QUEENS
# 91109         MONI      NaN        2013-11-18                QUEENS
# 91110      ANTHONY      NaN        2005-11-21                QUEENS
# ...            ...      ...               ...                   ...
# 2864493    CHARLES        A        2005-11-03                QUEENS
# 2864507    RICHARD      NaN        2013-05-16                QUEENS
# 2864512        NaN      NaN        1991-07-26             MANHATTAN
# 2864517       JOHN        W        1987-09-14              BROOKLYN
# 2864520        NaN      NaN        1995-04-02             MANHATTAN
#
#                            title_description leave_status_as_of_june_30  \
# 91106                     CORRECTION OFFICER                     ACTIVE
# 91107                     CORRECTION OFFICER                     ACTIVE
# 91108                     CORRECTION OFFICER                     ACTIVE
# 91109                    THERMOSTAT REPAIRER                     ACTIVE
# 91110                           CEMENT MASON                     CEASED
# ...                                      ...                        ...
# 2864493                              CAPTAIN                     CEASED
# 2864507                   CORRECTION OFFICER                     CEASED
# 2864512  POLICE OFFICER D/A DETECTIVE 2ND GR                     CEASED
# 2864517                          FIREFIGHTER                     CEASED
# 2864520  POLICE OFFICER D/A DETECTIVE 1ST GR                     CEASED
#
#          base_salary  pay_basis  regular_hours  regular_gross_paid  ot_hours  \
# 91106      82,808.00  per Annum       1,970.02           78,954.24    599.52
# 91107      43,042.00  per Annum       2,085.72           42,209.08    411.75
# 91108      43,042.00  per Annum          74.28              825.46      0.00
# 91109         368.08    per Day       1,825.00           99,381.60    927.00
# 91110         303.59    per Day           0.00            1,064.00      0.00
# ...              ...        ...            ...                 ...       ...
# 2864493   109,360.00  per Annum         -56.00           -2,927.19      0.00
# 2864507    89,391.00  per Annum         -56.00              217.80      0.00
# 2864512   109,360.00  per Annum           0.00                0.00      0.00
# 2864517    85,292.00  per Annum          -5.72             -233.05   -132.00
# 2864520   125,531.00  per Annum           0.00                0.00      0.00
#
#          total_ot_paid  total_other_pay                      today  \
# 91106        43,311.50        14,064.12 2022-05-16 22:11:42.508700
# 91107        12,887.34         2,951.43 2022-05-16 22:11:42.508700
# 91108             0.00             0.00 2022-05-16 22:11:42.508700
# 91109        98,482.83           788.74 2022-05-16 22:11:42.508700
# 91110             0.00             0.00 2022-05-16 22:11:42.508700
# ...                ...              ...                        ...
# 2864493           0.00       -18,831.37 2022-05-16 22:11:42.508700
# 2864507           0.00       -26,556.12 2022-05-16 22:11:42.508700
# 2864512           0.00       -27,662.62 2022-05-16 22:11:42.508700
# 2864517      -5,022.29       -23,835.73 2022-05-16 22:11:42.508700
# 2864520           0.00       -30,678.93 2022-05-16 22:11:42.508700
#
#          tenure_years
# 91106           11.00
# 91107            5.00
# 91108            4.00
# 91109            8.00
# 91110           16.00
# ...               ...
# 2864493         16.00
# 2864507          9.00
# 2864512         30.00
# 2864517         34.00
# 2864520         27.00
#
# [448809 rows x 19 columns]

# %%
(
    ggplot(df_agencies, 
           aes(x='total_ot_paid', y='ot_hours/regular_hours', color='tenure_years', size='total_ot_paid')) +
        geom_point(alpha=.5) +
        geom_hline(aes(yintercept=1), color='red') + 
        facet_grid('leave_status_as_of_june_30~fiscal_year') +
        scale_color_gradient(low='yellow',high='red') + 
        ggtitle('Overtime at NYPD, FD and Dept of Corrections') + 
        theme(figure_size=(16,9))

)
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 16346 rows containing missing values.
# <ggplot: (680688406)>

# %% [markdown]
# ## 🎯 Throughout the dataset, employees who clocked in the most overtime hours versus regualr hours are no longer on the payroll. Let's zoom into them.

# %%
(
    ggplot(df_agencies.query('leave_status_as_of_june_30 == "CEASED"'), 
           aes(x='total_ot_paid', y='ot_hours/regular_hours', color='tenure_years', size='total_ot_paid')) +
        geom_point(alpha=.5) +
        geom_hline(aes(yintercept=1), color='red') + 
        facet_wrap('fiscal_year') +
        scale_color_gradient(low='yellow',high='green') + 
        labs(
            title = "In 2020 and 2021, employees now retired clocked in the most overtime hrs vs regular hrs",
            y = "Ratio of overtime to regular hours worked",
            x = "Overtime earned"
        ) +
        theme(figure_size=(16,9))

)
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 15731 rows containing missing values.
# <ggplot: (687890895)>

# %%
df_agencies.query('ot_hours/regular_hours > 2').query('leave_status_as_of_june_30 == "CEASED"').query('regular_hours > 0')
# Out:
#          fiscal_year  payroll_number        agency_name    last_name  \
# 1705627         2020           56.00  POLICE DEPARTMENT       MURTHA
# 1763577         2020           56.00  POLICE DEPARTMENT       ANGEHR
# 1782979         2020           57.00    FIRE DEPARTMENT      CARLSON
# 1783746         2020           57.00    FIRE DEPARTMENT      MCNULTY
# 1783849         2020           57.00    FIRE DEPARTMENT       MURTHA
# 1783892         2020           57.00    FIRE DEPARTMENT  FITZGIBBONS
# 1783955         2020           57.00    FIRE DEPARTMENT   CICCARELLI
# 1783984         2020           57.00    FIRE DEPARTMENT        BURKE
# 1784058         2020           57.00    FIRE DEPARTMENT      MESSINA
# 1785130         2020           57.00    FIRE DEPARTMENT         COTO
# 2472171         2021           56.00  POLICE DEPARTMENT          NaN
# 2555582         2021           56.00  POLICE DEPARTMENT          NaN
# 2579145         2021           56.00  POLICE DEPARTMENT          NaN
# 2579408         2021           56.00  POLICE DEPARTMENT          NaN
# 2593163         2021           56.00  POLICE DEPARTMENT          NaN
# 2609498         2021           56.00  POLICE DEPARTMENT          NaN
# 2620473         2021           57.00    FIRE DEPARTMENT        PESCE
# 2630759         2021           57.00    FIRE DEPARTMENT      EDWARDS
# 2635833         2021           57.00    FIRE DEPARTMENT       WONICA
# 1785130         452.34        -1,871.96 2022-05-16 22:11:42.508700
# 2472171      30,054.70        32,513.24 2022-05-16 22:11:42.508700
# 2555582      15,271.75        28,495.92 2022-05-16 22:11:42.508700
# 2579145       5,738.20        34,643.43 2022-05-16 22:11:42.508700
# 2579408       7,599.05        31,763.85 2022-05-16 22:11:42.508700
# 2593163       9,117.25        25,087.98 2022-05-16 22:11:42.508700
# 2609498       3,598.80        25,965.55 2022-05-16 22:11:42.508700
# 2620473       6,751.86        19,422.90 2022-05-16 22:11:42.508700
# 2630759       3,703.02        17,775.21 2022-05-16 22:11:42.508700
# 2635833       5,004.38        14,409.67 2022-05-16 22:11:42.508700
# 2636537       3,340.36        15,835.76 2022-05-16 22:11:42.508700
# 2637287       3,366.66        15,544.42 2022-05-16 22:11:42.508700
# 2639420       3,340.36        14,675.23 2022-05-16 22:11:42.508700
# 2648418       3,289.30        10,911.86 2022-05-16 22:11:42.508700
# 2655614       2,636.45         8,749.76 2022-05-16 22:11:42.508700
# 2690092       3,987.09          -951.98 2022-05-16 22:11:42.508700
# 2697521       2,934.17        -2,017.78 2022-05-16 22:11:42.508700
# 2713005         470.38         2,071.66 2022-05-16 22:11:42.508700
#
#          tenure_years
# 1705627         27.00
# 1763577          6.00
# 1782979         28.00
# 1783746         21.00
# 1783849         17.00
# 1783892         21.00
# 1783955         14.00
# 1783984         17.00
# 1784058         14.00
# 1785130          6.00
# 2472171         23.00
# 2555582         26.00
# 2579145         29.00
# 2579408         25.00
# 2593163         22.00
# 2609498         25.00
# 2620473         25.00
# 2630759         20.00
# 2635833         20.00
# 2636537         20.00
# 2637287         22.00
# 2639420         18.00
# 2648418         14.00
# 2655614         13.00
# 2690092          2.00
# 2697521          2.00
# 2713005          3.00

# %%
len(df_agencies.query('ot_hours/regular_hours > 2').query('leave_status_as_of_june_30 == "CEASED"').query('regular_hours > 0'))
# Out:
# 27

# %%
df_agencies.query('ot_hours/regular_hours > 2').query('leave_status_as_of_june_30 == "CEASED"').query('regular_hours > 0').ot_hours.mean()
# Out:
# 195.22333333333336

# %%
(
    ggplot(df_agencies.query('leave_status_as_of_june_30 == "CEASED"'), 
           aes(x='total_ot_paid', y='ot_hours', color='tenure_years')) +
        geom_point(alpha=.5) +
        facet_grid('agency_name~fiscal_year') +
        labs(
            title = "In 2020 and 2021, employees now retired clocked in the most overtime hrs vs regular hrs",
            y = "Overtime hours worked",
            x = "Overtime earned"
        ) +
        theme(figure_size=(18,10))

)
# Out:
# <ggplot: (680826265)>

# %% [markdown]
# ### 🎯 2020 and 2021 showed the highest range of overtime hours worked with some employees clocking over 1000 hours. Most of these employees are in the 20-40 year tenure bracket.
#
#
# ### With this in mind, let's look at how tenure impacts overtime for all enmployees across all agencies. Here we'll plot overtime hours worked and overtime earned faceted by fiscal year and leave status

# %%
(
    ggplot(df.query('regular_hours > 0').query('ot_hours > 0'), 
           aes(x='tenure_years', y='ot_hours/regular_hours')) +
        geom_point(alpha=.5) +
        facet_wrap('fiscal_year') +
        geom_hline(aes(yintercept=1), color='red') + 
#         geom_vline(aes(xintercept=1), color='yellow') +
        labs(
            title = "Employees clock in the more overtime hrs vs regular hrs as they add years to their tenure",
            y = "Ratio of overtime to regular hours",
            x = "Tenure"
        ) +
        theme(figure_size=(10,6))

)
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 38 rows containing missing values.
# <ggplot: (375882951)>

# %%
(
    ggplot(df.query('regular_hours > 0').query('ot_hours > 0').query('leave_status_as_of_june_30 == "CEASED"'), 
           aes(x='tenure_years', y='ot_hours/regular_hours')) +
        geom_point(alpha=.5) +
        geom_hline(aes(yintercept=1), color='red') +
        geom_vline(aes(xintercept=17), color='yellow') +
        geom_vline(aes(xintercept=30), color='yellow') +
        facet_wrap('work_location_borough') +
        labs(
            title = "As employees near retirement, they clock in more overtime hours compared to regular hours",
            y = "Overtime hours",
            x = "Tenure"
        ) +
        theme(figure_size=(10,8))

)
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 5 rows containing missing values.
# <ggplot: (687290399)>

# %%
df.query('first_name == "KEVIN"').query('last_name == "MURTHA"').query('agency_start_date == "1995-04-30"').total_ot_paid.sum()
# Out:
# 332554.82

# %%
df.query('first_name == "KEVIN"').query('last_name == "MURTHA"').query('agency_start_date == "1995-04-30"')
# Out:
#          fiscal_year  payroll_number        agency_name last_name first_name  \
# 539518          2017             NaN  POLICE DEPARTMENT    MURTHA      KEVIN
# 1082287         2018           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 1697037         2019           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
# 1705627         2020           56.00  POLICE DEPARTMENT    MURTHA      KEVIN
#
#         mid_init agency_start_date work_location_borough  \
# 539518       NaN        1995-04-30              BROOKLYN
# 1082287      NaN        1995-04-30              BROOKLYN
# 1697037      NaN        1995-04-30              BROOKLYN
# 1705627      NaN        1995-04-30             MANHATTAN
#
#                          title_description leave_status_as_of_june_30  \
# 539518   LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE
# 1082287  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE
# 1697037  LIEUTENANT D/A SPECIAL ASSIGNMENT                     ACTIVE
# 1705627  LIEUTENANT D/A SPECIAL ASSIGNMENT                     CEASED
#
#          base_salary  pay_basis  regular_hours  regular_gross_paid  ot_hours  \
# 539518    134,067.00  per Annum       2,051.43          132,640.94    433.70
# 1082287   138,089.00  per Annum       2,045.72          134,294.80    536.33
# 1697037   138,089.00  per Annum       2,040.00          137,710.56    387.87
# 1705627   141,196.00  per Annum         665.18           48,008.86  2,451.57
#
#          total_ot_paid  total_other_pay                      today  \
# 539518       50,799.80        28,006.50 2022-05-16 22:11:42.508700
# 1082287      62,473.98        27,815.30 2022-05-16 22:11:42.508700
# 1697037      57,280.57        25,084.00 2022-05-16 22:11:42.508700
# 1705627     162,000.47        78,132.88 2022-05-16 22:11:42.508700
#
#          tenure_years
# 539518          27.00
# 1082287         27.00
# 1697037         27.00
# 1705627         27.00

# %%
(
    ggplot(df.query('regular_hours > 0').query('ot_hours > 0').query('leave_status_as_of_june_30 == "CEASED"'), 
           aes(x='tenure_years', y='ot_hours/regular_hours')) +
        geom_point(alpha=.5) +
        geom_hline(aes(yintercept=1), color='red') +
        geom_vline(aes(xintercept=17), color='yellow') +
        geom_vline(aes(xintercept=30), color='yellow') +
        labs(
            title = "As employees near retirement, they clock in more overtime hours compared to regular hours",
            y = "Ratio of overtime to regular hours",
            x = "Tenure"
        ) +
        theme(figure_size=(8,6))

)
# Out:
# /Users/areena.arora/.pyenv/versions/3.10.0/lib/python3.10/site-packages/plotnine/layer.py:401: PlotnineWarning: geom_point : Removed 5 rows containing missing values.
# <ggplot: (687247198)>

# %%
model = smf.ols('ot_hours ~ regular_hours + work_location_borough + agency_name', data=df_agencies) 
results = model.fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ot_hours   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.228
# Method:                 Least Squares   F-statistic:                 2.207e+04
# Date:                Mon, 16 May 2022   Prob (F-statistic):               0.00
# Time:                        22:19:10   Log-Likelihood:            -3.0445e+06
# No. Observations:              448809   AIC:                         6.089e+06
# Df Residuals:                  448802   BIC:                         6.089e+06
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                            -47.9774      1.674    -28.653      0.000     -51.259     -44.696
# work_location_borough[T.BROOKLYN]     -3.7545      1.117     -3.362      0.001      -5.943      -1.566
# work_location_borough[T.MANHATTAN]    43.2550      1.077     40.144      0.000      41.143      45.367
# work_location_borough[T.QUEENS]        3.6591      1.127      3.248      0.001       1.451       5.867
# agency_name[T.FIRE DEPARTMENT]        39.9721      1.188     33.658      0.000      37.644      42.300
# agency_name[T.POLICE DEPARTMENT]     -76.8922      1.034    -74.339      0.000     -78.919     -74.865
# regular_hours                          0.1805      0.001    324.954      0.000       0.179       0.182
# ==============================================================================
# Omnibus:                    96872.599   Durbin-Watson:                   1.301
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           260718.977
# Skew:                           1.161   Prob(JB):                         0.00
# Kurtosis:                       5.923   Cond. No.                     1.32e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model = smf.ols('ot_hours ~ base_salary + agency_name + tenure_years', data=df_agencies) 
results = model.fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ot_hours   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     9748.
# Date:                Mon, 16 May 2022   Prob (F-statistic):               0.00
# Time:                        22:20:47   Log-Likelihood:            -3.0838e+06
# No. Observations:              448809   AIC:                         6.168e+06
# Df Residuals:                  448804   BIC:                         6.168e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                          179.8181      1.169    153.868      0.000     177.528     182.109
# agency_name[T.FIRE DEPARTMENT]      56.8349      1.197     47.480      0.000      54.489      59.181
# agency_name[T.POLICE DEPARTMENT]   -65.5916      1.002    -65.484      0.000     -67.555     -63.628
# base_salary                          0.0014   1.24e-05    113.508      0.000       0.001       0.001
# tenure_years                        -0.0177      0.046     -0.381      0.703      -0.109       0.073
# ==============================================================================
# Omnibus:                    85657.981   Durbin-Watson:                   1.282
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           186181.723
# Skew:                           1.114   Prob(JB):                         0.00
# Kurtosis:                       5.234   Cond. No.                     3.72e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
